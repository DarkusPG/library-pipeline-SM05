# %%
# In Jupyter notebook
import sys
sys.path.append('C:\\Users\\Admin\\Documents\\GitHub\\library-pipeline-SM05\\src')

from data_processing.ingestion import load_csv, load_json, load_excel

# Excel CSV loading
df_excel = load_excel('../data/catalogue.xlsx')
print(f"Loaded {len(df_excel)} catalogue")
print(df_excel.head())

# Test CSV loading
df_circ = load_csv('../data/circulation_data.csv')
print(f"Loaded {len(df_circ)} circulation records")
print(df_circ.head())

# Test JSON loading
df_events = load_json('../data/events_data.json')
print(f"Loaded {len(df_events)} events")
print(df_events.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 5
#       2 import sys
#       3 sys.path.append('C:\\Users\\Admin\\Documents\\GitHub\\library-pipeline-SM05\\src')
# ----> 5 from data_processing.ingestion import load_csv, load_json, load_excel
#       7 # Excel CSV loading
#       8 df_excel = load_excel('../data/catalogue.xlsx')
#
# ImportError: cannot import name 'load_excel' from 'data_processing.ingestion' (C:\Users\Admin\Documents\GitHub\library-pipeline-SM05\src\data_processing\ingestion.py)

# %%
# In Jupyter notebook
import sys
sys.path.append('C:\\Users\\Admin\\Documents\\GitHub\\library-pipeline-SM05\\src')

from data_processing.ingestion import load_excel

# Excel CSV loading
df_excel = load_excel('../data/catalogue.xlsx')
print(f"Loaded {len(df_excel)} catalogue")
print(df_excel.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 5
#       2 import sys
#       3 sys.path.append('C:\\Users\\Admin\\Documents\\GitHub\\library-pipeline-SM05\\src')
# ----> 5 from data_processing.ingestion import load_excel
#       7 # Excel CSV loading
#       8 df_excel = load_excel('../data/catalogue.xlsx')
#
# ImportError: cannot import name 'load_excel' from 'data_processing.ingestion' (C:\Users\Admin\Documents\GitHub\library-pipeline-SM05\src\data_processing\ingestion.py)
